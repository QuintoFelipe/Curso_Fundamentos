# %% [markdown]
# <div style="background-color: #d1e7dd; padding: 20px; border-radius: 10px;">
#         <h1 style="color: #000000;"><b>PRUEBA 2 - SOLUCIÓN</h1>
#         <h3 style="color: #000000;">Fundamentos 2024 II </h3>
#         <p style="font-size: 18px; color: #000000;">
#             <b>INTEGRANTES:</b><br>
#
#         Cristian Jiménez         CC 1020460089
#         Juan Felipe Quinto Rios  CC 1041152117
#         Veronica Arango Toro     CC 1039473234

# %% [markdown]
# # **Prueba #2**
# En la siguiente pureba se evalua de manera EXCLUSIVA lo que se solicita, cualquier otra respuesta adicional a ella será valorada, más no evaluada. Entregue la prueba en un repositorio de github antes de el domingo 18 de Agosto a las 23:59:59 hora colombiana.

# %% [markdown]
# ---

# %% [markdown]
# ## **Ejercicio 1** (50%)
#
# Construya un DataFrame a partir del siguiente diccionario
#
# `exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], 'score': [12.5, 9, 16.5, 10, 9, 20, 14.5, 12, 8, 19], 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1], 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}`
#
# con las siguientes etiquetas para los índices
#
# `labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']`
#
# 1. Seleccione solo las columnas *name* y *score*.
#
# 2. Filtre las filas donde el número de intentos (attemps) sea mayor que 2.
#
# 3. Filtre las filas donde el *score* se encuentre entre 15 y 20 (incluidos)
#
# 4. Cambie el *score* en la fila 'd' a 11.5
#
# 5. Agregue una nueva fila con etiqueta 'k' al dataframe con un valor que usted desee para cada columna
#
# 6. Borre la fila 'k' y entregue nuevamente el DataFrame original.
#
# 7. Ordene el DataFrame por nombre en orden ascendente.
#
# 8. Reemplace los valores de la columna *qualify* que contiene los valores *yes* y *no* por los valores booleanos True y False respectivamente.

# %% [markdown]
# ---
#
# ## **Solucion Ejercicio 1**

# %%
import pandas as pd

# %% [markdown]
# Creamos un DataFrame a partir del diccionario dado y usaremos las etiquetas especificadas como el indice

# %%
exam_data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, 10, 9, 20, 14.5, 12, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
print("DataFrame Original:")
df
# Out:
# DataFrame Original:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   10.0         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura   12.0         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ### 1. Seleccione solo las columnas *'name'* y *'score'*.
# Para seleccionar columnas específicas, hacemos lo siguiente:

# %%
print("Columnas seleccionadas 'name' y 'score':")
df.loc[:, ['name', 'score']]
# Out:
# Columnas seleccionadas 'name' y 'score':
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James   10.0
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura   12.0
# i      Kevin    8.0
# j      Jonas   19.0

# %% [markdown]
# ### 2. Filtre las filas donde el número de intentos (`attemps`) sea mayor que 2.
#
# Podemos filtrar filas según una condición:

# %%
print("Filas donde attempts son mayores a 2:")
df.loc[df.attempts > 2]
# Out:
# Filas donde attempts son mayores a 2:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James   10.0         3      no
# f  Michael   20.0         3     yes

# %% [markdown]
# ### 3. Filtre las filas donde el *score* se encuentre entre 15 y 20 (incluidos)
#
# Para filtrar basado en el puntaje, usamos:

# %%
print("Filas donde el score está entre 15 y 20:")
df.loc[(df.score >= 15) & (df.score <= 20)]
# Out:
# Filas donde el score está entre 15 y 20:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# Otra alternativa usando el método between

# %%
print("Filas donde el score está entre 15 y 20:")
df.loc[df.score.between(15, 20)]
# Out:
# Filas donde el score está entre 15 y 20:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# ### 4. Cambie el *score* en la fila 'd' a 11.5
#
# Podemos modificar el DataFrame especificando el índice:

# %%
print("DataFrame después de cambiar el score en la fila 'd' a 11.5:")
df.loc[df.index == 'd', 'score'] = 11.5
df
# Out:
# DataFrame después de cambiar el score en la fila 'd' a 11.5:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura   12.0         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ### 5. Agregue una nueva fila con etiqueta 'k' al dataframe con un valor que usted desee para cada columna
#
# Podemos agregar una nueva fila utilizando el método `loc`:

# %%
print("DataFrame después de agregar la nueva fila 'k':")
df.loc['k'] = ['Nuevo Nombre', 18, 2, 'yes']
df
# Out:
# DataFrame después de agregar la nueva fila 'k':
#            name  score  attempts qualify
# a     Anastasia   12.5         1     yes
# b          Dima    9.0         3      no
# c     Katherine   16.5         2     yes
# d         James   11.5         3      no
# e         Emily    9.0         2      no
# f       Michael   20.0         3     yes
# g       Matthew   14.5         1     yes
# h         Laura   12.0         1      no
# i         Kevin    8.0         2      no
# j         Jonas   19.0         1     yes
# k  Nuevo Nombre   18.0         2     yes

# %% [markdown]
# ### 6. Borre la fila 'k' y entregue nuevamente el DataFrame original.
#
# Para eliminar una fila, usamos el método `drop`:

# %%
print("DataFrame después de eliminar la fila 'k':")
df = df.drop('k')
df
# Out:
# DataFrame después de eliminar la fila 'k':
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura   12.0         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ### 7. Ordene el DataFrame por nombre en orden ascendente.
#
# Podemos ordenar el DataFrame utilizando el método `sort_values`:

# %%
print("DataFrame ordenado por name:")
df = df.sort_values('name', ascending=True)
df
# Out:
# DataFrame ordenado por name:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# e      Emily    9.0         2      no
# d      James   11.5         3      no
# j      Jonas   19.0         1     yes
# c  Katherine   16.5         2     yes
# i      Kevin    8.0         2      no
# h      Laura   12.0         1      no
# g    Matthew   14.5         1     yes
# f    Michael   20.0         3     yes

# %% [markdown]
# ### 8. Reemplace los valores de la columna *qualify* que contiene los valores *yes* y *no* por los valores booleanos True y False respectivamente.
#
# Finalmente, reemplazamos los valores en la columna qualify:

# %%
print("DataFrame después de reemplazar 'yes' y 'no' en la columna qualify con True y False:")
df['qualify'] = df['qualify'].map({'yes': True, 'no': False})
df
# Out:
# DataFrame después de reemplazar 'yes' y 'no' en la columna qualify con True y False:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# e      Emily    9.0         2    False
# d      James   11.5         3    False
# j      Jonas   19.0         1     True
# c  Katherine   16.5         2     True
# i      Kevin    8.0         2    False
# h      Laura   12.0         1    False
# g    Matthew   14.5         1     True
# f    Michael   20.0         3     True

# %% [markdown]
# ---

# %% [markdown]
# ## **Ejercicio 2** (50%)
#
# Importe el dataset `athletes` del [repositorio del curso](https://github.com/tomasate/Datos_Clases/tree/main/Datos_1) y realice las siguientes tareas:
#
# 1. Importarlo como nombre athletes
# 2. Filtre el dataframe tal que solo se quede con los atletas que hayan ganado al menos una medalla.
# 3. Calcule la masa muscular por fila con una función como
#
# $$I_{m.m.} = \frac{Weight}{Height^2}$$
#
# 4. Agrupe los datos por el calculo de la media por deporte para cada una del resto de características. ¿Cuál es el deporte en el que los jugadores tienen mayor peso promedio?
#
# 5. ¿Cuál es el pais con más participación total femenina?

# %% [markdown]
# ---
#
# ## **Solucion Ejercicio 2**

# %% [markdown]
# ### 1. Importarlo como nombre athletes

# %%
import pandas as pd

print('DataFrame athletes importado:')
athletes = pd.read_csv('https://raw.githubusercontent.com/tomasate/Datos_Clases/main/Datos_1/athletes.csv')
athletes.head()
# Out:
# DataFrame athletes importado:
#           id            name nationality     sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0
# 1    fencing     0       0       0
# 2  athletics     0       0       1
# 3  taekwondo     0       0       0
# 4    cycling     0       0       0

# %% [markdown]
# ### 2.Filtrar el DataFrame para Quedarse Solo con los Atletas que Hayan Ganado al Menos una Medalla
#
# Vamos a sumar las columnas de medallas (gold, silver, bronze) para determinar qué atletas han ganado al menos una medalla.

# %%
athletes['total_medals'] = athletes['gold'] + athletes['silver'] + athletes['bronze']
athletes_with_medals = athletes.loc[athletes.total_medals > 0]
print("Atletas que han ganado al menos una medalla:")
athletes_with_medals.head()
# Out:
# Atletas que han ganado al menos una medalla:
#            id                         name nationality     sex       dob  \
# 2   435962603                  Aaron Brown         CAN    male   5/27/92
# 6   266237702                Aaron Russell         USA    male    6/4/93
# 14  162792594               Abbey Weitzeil         USA  female   12/3/96
# 48  962468808  Abdoulrazak Issoufou Alfaga         NIG    male  12/26/94
# 55  969824503           Abdullah Alrashidi         IOA    male   8/21/63
#
#     height  weight       sport  gold  silver  bronze  total_medals
# 2     1.98    79.0   athletics     0       0       1             1
# 6     2.05    98.0  volleyball     0       0       1             1
# 14    1.78    68.0    aquatics     1       1       0             2
# 48    2.07    98.0   taekwondo     0       1       0             1
# 55    1.83    84.0    shooting     0       0       1             1

# %% [markdown]
# **3. Calcule la masa muscular por fila con una función**

# %% [markdown]
# Nos podemos dar cuenta que en las columnas de peso y altura hay valores nulos

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            11538 non-null  int64
#  1   name          11538 non-null  object
#  2   nationality   11538 non-null  object
#  3   sex           11538 non-null  object
#  4   dob           11537 non-null  object
#  5   height        11208 non-null  float64
#  6   weight        10879 non-null  float64
#  7   sport         11538 non-null  object
#  8   gold          11538 non-null  int64
#  9   silver        11538 non-null  int64
#  10  bronze        11538 non-null  int64
#  11  total_medals  11538 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.1+ MB

# %%
import matplotlib.pyplot as plt

# Plotting the distributions
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Distribution for height
axes[0].hist(athletes['height'].dropna(), bins=30, color='skyblue', edgecolor='black')
axes[0].set_title('Height Distribution')
axes[0].set_xlabel('Height (cm)')
axes[0].set_ylabel('Frequency')

# Distribution for weight
axes[1].hist(athletes['weight'].dropna(), bins=30, color='lightgreen', edgecolor='black')
axes[1].set_title('Weight Distribution')
axes[1].set_xlabel('Weight (kg)')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Usamos imputacion mediante la media de los datos para el peso y la altura

# %%
athletes.fillna({'weight': athletes.weight.mean(), 'height': athletes.height.mean()}, inplace=True)
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            11538 non-null  int64
#  1   name          11538 non-null  object
#  2   nationality   11538 non-null  object
#  3   sex           11538 non-null  object
#  4   dob           11537 non-null  object
#  5   height        11538 non-null  float64
#  6   weight        11538 non-null  float64
#  7   sport         11538 non-null  object
#  8   gold          11538 non-null  int64
#  9   silver        11538 non-null  int64
#  10  bronze        11538 non-null  int64
#  11  total_medals  11538 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# Observamos la nueva distribución

# %%
# Plotting the distributions
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Distribution for height
axes[0].hist(athletes['height'].dropna(), bins=30, color='skyblue', edgecolor='black')
axes[0].set_title('Height Distribution')
axes[0].set_xlabel('Height (cm)')
axes[0].set_ylabel('Frequency')

# Distribution for weight
axes[1].hist(athletes['weight'].dropna(), bins=30, color='lightgreen', edgecolor='black')
axes[1].set_title('Weight Distribution')
axes[1].set_xlabel('Weight (kg)')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Se define la función para calcular la masa muscular
def calcular_masa_muscular(df):
    return df['weight'] / df['height']**2

# %%
# Se crea la nueva columna 'masa muscular' utilizando el método apply y la función creada anteriormente
athletes['imm'] = athletes.apply(calcular_masa_muscular, axis=1)
athletes
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB  female   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE  female  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    male   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    male    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    male    1/6/92    1.85
#
# ...

# %% [markdown]
# **4. Agrupe los datos calculando la media por deporte para cada una del resto de características. ¿Cuál es el deporte en el que los jugadores tienen mayor peso promedio?**

# %%
grouped_by_sport = athletes.groupby('sport').mean(numeric_only=True).sort_values('weight', ascending=False)
grouped_by_sport
# Out:
#                              id    height     weight      gold    silver  \
# sport
# basketball         5.036080e+08  1.918715  87.532197  0.083333  0.083333
# handball           4.957886e+08  1.837080  83.261584  0.079890  0.082645
# volleyball         4.844270e+08  1.896188  80.060251  0.072917  0.070312
# weightlifting      5.004174e+08  1.666628  79.980620  0.058140  0.058140
# rowing             5.095929e+08  1.847652  79.765664  0.087751  0.087751
# rugby sevens       5.228671e+08  1.755729  78.657349  0.083333  0.080000
# wrestling          4.937765e+08  1.723368  77.677827  0.050992  0.050992
# canoe              5.019726e+08  1.780873  76.955507  0.081571  0.081571
# judo               4.903510e+08  1.736155  76.729129  0.035714  0.035714
# shooting           4.877244e+08  1.729344  73.858159  0.038462  0.038462
# tennis             4.971817e+08  1.801334  73.134393  0.040816  0.040816
# aquatics           4.997725e+08  1.787590  72.294213  0.083045  0.077509
# ...

# %%
print(f"El deporte con el mayor peso promedio es {grouped_by_sport.iloc[0].name} con un peso promedio de {round(grouped_by_sport.iloc[0].weight,2)} kg.")
# Out:
# El deporte con el mayor peso promedio es basketball con un peso promedio de 87.53 kg.

# %% [markdown]
# **5. ¿Cuál es el pais con más participación total femenina?**

# %%
female_participation_by_country = athletes.loc[:, ['nationality', 'sex']].loc[athletes.sex == 'female'].groupby('nationality').count().sort_values('sex', ascending=False)
female_participation_by_country
# Out:
#              sex
# nationality
# USA          303
# CHN          251
# AUS          220
# BRA          216
# GER          204
# ...          ...
# SOM            1
# SSD            1
# STP            1
# ASA            1
# AFG            1
#
# [202 rows x 1 columns]

# %%
print(f"El pais con la mayor participacion femenina es {female_participation_by_country.iloc[0].name} con {female_participation_by_country.iloc[0].sex} participantes.")
# Out:
# El pais con la mayor participacion femenina es USA con 303 participantes.
